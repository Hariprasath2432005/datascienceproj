# %%
import seaborn as sns
sns.get_dataset_names()
# Out:
# ['anagrams',
#  'anscombe',
#  'attention',
#  'brain_networks',
#  'car_crashes',
#  'diamonds',
#  'dots',
#  'dowjones',
#  'exercise',
#  'flights',
#  'fmri',
#  'geyser',
#  'glue',
#  'healthexp',
#  'iris',
#  'mpg',
#  'penguins',
#  'planets',
#  'seaice',
#  'taxis',
#  'tips',
#  'titanic']

# %%
import matplotlib.pyplot as plt

#load planets dataset
p=sns.load_dataset('titanic')

#display first few rows
p.head(80)
# Out:
#     survived  pclass     sex    age  sibsp  parch     fare embarked   class  \
# 0          0       3    male  22.00      1      0   7.2500        S   Third
# 1          1       1  female  38.00      1      0  71.2833        C   First
# 2          1       3  female  26.00      0      0   7.9250        S   Third
# 3          1       1  female  35.00      1      0  53.1000        S   First
# 4          0       3    male  35.00      0      0   8.0500        S   Third
# ..       ...     ...     ...    ...    ...    ...      ...      ...     ...
# 75         0       3    male  25.00      0      0   7.6500        S   Third
# 76         0       3    male    NaN      0      0   7.8958        S   Third
# 77         0       3    male    NaN      0      0   8.0500        S   Third
# 78         1       2    male   0.83      0      2  29.0000        S  Second
# 79         1       3  female  30.00      0      0  12.4750        S   Third
#
#       who  adult_male deck  embark_town alive  alone
# ...

# %%
plt.figure(figsize=(10,8))
sns.countplot(x='age',data=p)
plt.show()

# %%
plt.figure(figsize=(10,8))
sns.barplot(x='age',y='sex',data=p)                        #x=axis -->categorical            y=axis-->int
plt.show()

# %%
#kde=> kernel distribution estimation
plt.figure(figsize=(6,4))
sns.histplot(p['fare'],bins=20,kde=True,color='black')
plt.show()

# %%
counts=p['survived'].value_counts()
counts
# Out:
# survived
# 0    549
# 1    342
# Name: count, dtype: int64

# %%
#SMOT-SYNTHYETIC MINORITY OVERSAMOLING TECHNIQUE( imblanced data to balance data)
#i)oversampling             yes athigama iruntha
#ii)undersampling          no athigama iruntha

plt.figure(figsize=(4,6))
plt.pie(counts,labels=['Did Not survive','survived	'],colors=['skyblue','blue'],autopct='%1.1f%%')
plt.show()
# Out:
# C:\Users\admin\AppData\Roaming\Python\Python313\site-packages\IPython\core\pylabtools.py:170: UserWarning: Glyph 9 (	) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)

# %%
plt.figure(figsize=(4,6))
sns.boxplot(x='fare',data=p,palette='Set1')
plt.title('Fare Distribution by passengers class')                   #iqr

plt.xlabel('class')
plt.ylabel('Fare')
plt.show()
# Out:
# C:\Users\admin\AppData\Local\Temp\ipykernel_13968\3089103035.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(x='fare',data=p,palette='Set1')

# %%
plt.figure(figsize=(5,8))
sns.scatterplot(x='age',y='fare',hue='survived',style='sex',data=p,palette='rainbow')           #palette=coolwarm
plt.title('Age vs Fare with Survival and Gender')
plt.xlabel('age')
plt.ylabel('Fare')
plt.legend(title='Survived')
plt.show()

# %%
numerical=p[['survived','pclass','age','sibsp','parch','fare']].corr()
numerical
# Out:
#           survived    pclass       age     sibsp     parch      fare
# survived  1.000000 -0.338481 -0.077221 -0.035322  0.081629  0.257307
# pclass   -0.338481  1.000000 -0.369226  0.083081  0.018443 -0.549500
# age      -0.077221 -0.369226  1.000000 -0.308247 -0.189119  0.096067
# sibsp    -0.035322  0.083081 -0.308247  1.000000  0.414838  0.159651
# parch     0.081629  0.018443 -0.189119  0.414838  1.000000  0.216225
# fare      0.257307 -0.549500  0.096067  0.159651  0.216225  1.000000

# %%
numerical=p[['survived','pclass','age','sibsp','parch','fare']].corr()

plt.figure(figsize=(4,4))
sns.heatmap(numerical,annot=True,cmap='coolwarm',center=1)                #color-->coolwarm=rainbow
plt.title('Correlation heatmap of Titanic Dataset')
plt.show()                               

#only int values

# %%
plt.figure(figsize=(7,8))
sns.violinplot(x='class',y='age',hue='survived',data=p,split=False,palette='Set1')
plt.title('age Distribution by Class and Survival')
plt.xlabel('Class')
plt.ylabel('Age')
plt.legend(title='Survived')
plt.show()
#combination of box plot and KDE to show distribution shape ,spred and outliers(KDE-->KERNAL DENSITY ESTIMATION)

# %%
sns.kdeplot(data=p['age'].dropna(),color='red',fill=True)
plt.title('Age Distribution')
plt.xlabel('fare')
plt.ylabel('density')
plt.show()
#only int

# %%
sns.pairplot(p)

# %%
sns.pairplot(p[['age','fare','class','survived','sex']])

# %%
plt.figure(figsize=(5,5))
sns.swarmplot(x='class',y='age',hue='survived',data=p,palette='Set2',dodge=False)
plt.title('Age Distribution by class and survival (Swarm Plot') 
plt.xlabel('class')
plt.ylabel('age')
plt.legend(title='Survived')
plt.show()

#advanced model of violinplot
# Out:
# c:\Users\admin\AppData\Local\Programs\Python\Python313\Lib\site-packages\seaborn\categorical.py:3399: UserWarning: 12.7% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# c:\Users\admin\AppData\Local\Programs\Python\Python313\Lib\site-packages\seaborn\categorical.py:3399: UserWarning: 26.2% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)

# %%
g=sns.FacetGrid(p,col='class',row='survived',margin_titles=True)
g.map(sns.histplot,'age',bins=20, color='yellow')
g.fig.suptitle('age distribution by class and survival',y=1.03)
# Out:
# Text(0.5, 1.03, 'age distribution by class and survival')
